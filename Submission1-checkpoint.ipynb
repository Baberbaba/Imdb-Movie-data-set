# %% [markdown]
# # Assignment 1 Baber Ahmad Baba

# %% [markdown]
# # Scenraio:
#   I am working for `Smith Work Studios` as a `Data Analyst`, and i was provided with data on previous movies from **IMDB**

# %%
# importing required libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the data set

# %%
# assigning a variable for the data set so that it would be easier ahead
movies = pd.read_csv(r'D:\Python\Movie Assignment Data.csv')

# %%
movies
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %% [markdown]
# ##  We have converted the file as an `Pandas DataFrame `

# %% [markdown]
# ### By Visualizing the DataFrame we can manipulate the data as per our requirements.
# - Getting rid of unneseccary columns and rows
# - Genrating a breif description of each column
# - Filter a column based on another column

# %%
# dropping unnesaccary columns and assigning it to variable so that we can later access the original dataframe
detailed_movies = movies.drop(movies.iloc[:,14:-2],axis =1)
detailed_movies
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %%
# lets describe the contents of data frame and assign it to a variable 
description = detailed_movies.describe()
description
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %%
# Genrating descriptive statistics for the budget of all the movies
# assigning it to a variable 
movie_budget = description['budget']
movie_budget
# Out:
# count    1.000000e+02
# mean     7.838400e+07
# std      7.445295e+07
# min      3.000000e+06
# 25%      1.575000e+07
# 50%      4.225000e+07
# 75%      1.500000e+08
# max      2.600000e+08
# Name: budget, dtype: float64

# %% [markdown]
# ### Since the budget values are not much readable lets make them a bit more understandable

# %%
# rounding the values to the nearest decimal place since the value would be approximate
print(f'The budget of all the movies follow the following pattern: \n{round(movie_budget)}')
# Out:
# The budget of all the movies follow the following pattern:
# count          100.0
# mean      78384000.0
# std       74452947.0
# min        3000000.0
# 25%       15750000.0
# 50%       42250000.0
# 75%      150000000.0
# max      260000000.0
# Name: budget, dtype: float64

# %% [markdown]
# ## Now we have accessed the stastical description of budget of all movies.
# ## We can easily get the following :
# - Total number of movies in the dataframe from **count**.
# - **Mean** of the budget.
# - **Standard deviation** of budget.
# - **Min** and **Max** in the budget.

# %% [markdown]
# ## Now Filtering the data depending on various column prefrences:

# %%
# executing the dataframe once more
detailed_movies
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %% [markdown]
# ## Now we want the number of  Top-rated movies having `Pg-13` rating produced in `USA`

# %%
# Sorting the DataFrame as per the rating and assigning it to variable
sorted_movies = detailed_movies.sort_values(by='IMDb_rating',ascending=False)
sorted_movies
# Out:
#                           Title  title_year     budget      Gross  \
# 27                    Inception        2010  160000000  292568851
# 26                 Interstellar        2014  165000000  187991439
# 95                     Whiplash        2014    3300000   13092000
# 8         The Dark Knight Rises        2012  250000000  448130642
# 35             Django Unchained        2012  100000000  162804648
# ..                          ...         ...        ...        ...
# 60                      Sicario        2015   30000000   46875468
# 99      Tucker and Dale vs Evil        2010    5000000     223838
# 46  Scott Pilgrim vs. the World        2010   60000000   31494270
# 52                Lone Survivor        2013   40000000  125069696
# 22                         Hugo        2011  170000000   73820094
#
#            actor_1_name       actor_2_name          actor_3_name  \
# 27    Leonardo DiCaprio          Tom Hardy  Joseph Gordon-Levitt
# ...

# %% [markdown]
# ## Now for the sorted DataFrame we need to filter as per country and content rating

# %%
# using the loc function to filter the columns based on each other
filtered_movies = sorted_movies.loc[sorted_movies['Country']=='USA'].loc[sorted_movies['content_rating']=='PG-13']
# Checking the count and assigning it to variable 
number_of_movies = filtered_movies['Title'].count()
print(f'Number of the top-rated movies produced in the United States having PG-13 rating is {number_of_movies}')
# Out:
# Number of the top-rated movies produced in the United States having PG-13 rating is 35

# %% [markdown]
# ### We sorted the movies in descending order of _imdb rating_ and later filtered it based on _Country_ and _content rating_

# %%
# filtering again using the loc function and assigning it to a variable 
non_us_movies = sorted_movies.loc[sorted_movies['title_year']==2014].loc[sorted_movies['Country']!='USA']
non_us_movies
# Out:
#                        Title  title_year    budget      Gross  \
# 81        The Imitation Game        2014  14000000   91121452
# 45            The Lego Movie        2014  60000000  257756197
# 80                Ex Machina        2014  15000000   25440971
# 78  The Theory of Everything        2014  15000000   35887263
#
#             actor_1_name   actor_2_name    actor_3_name  \
# 81  Benedict Cumberbatch   Rory Kinnear     Allen Leech
# 45        Morgan Freeman   Will Ferrell     Alison Brie
# 80         Elina Alminas  Sonoya Mizuno   Corey Johnson
# 78        Eddie Redmayne   Emily Watson  Simon McBurney
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 81                   19000                   393.0                   305.0
# 45                   11000                  8000.0                  2000.0
# 80                     149                   145.0                   123.0
# ...

# %%
# checking the count of non us movies and assigning it to variable
number_non_us = non_us_movies['Title'].count()

# %%
# checking the  non_us_movies and creating a series based on it
# since in number_non_us will have index from 0 we need to specify our range from 1-4
title_non_us = pd.Series(non_us_movies['Title'].values,index=(np.arange(1,number_non_us+1)))

# %%
# Printing the number of movies and the movies in series
print(f'Top-rated movies of 2014 which were were not produced in the United States are:\n{title_non_us}')
# Out:
# Top-rated movies of 2014 which were were not produced in the United States are:
# 1          The Imitation Game
# 2              The Lego Movie
# 3                  Ex Machina
# 4    The Theory of Everything
# dtype: object

# %% [markdown]
# ### In the above case we filtered the already sorted movies based on year 2014 and checked for the movies that were not produced in USA. We did it in follwing manner:
# 1. Filtered as per particular rows using the `loc()` function
#    - Assigned the newly filterd DataFrame to a variable.
#    > - Checked the number of movies that we got from the data frame using `count()` function.
#    > > - Assigned it to another variable.
#
#
# 2. Created a Series of title of movies form the previous DataFrame and index of number of movies.
#    - Used the `values` method to get the values without the index.
#    > - Created a Numpy array using `np.arange()`function.

# %%
# Since we again need to check for top rated movies, we have already assigned a varaible for that
sorted_movies
# Out:
#                           Title  title_year     budget      Gross  \
# 27                    Inception        2010  160000000  292568851
# 26                 Interstellar        2014  165000000  187991439
# 95                     Whiplash        2014    3300000   13092000
# 8         The Dark Knight Rises        2012  250000000  448130642
# 35             Django Unchained        2012  100000000  162804648
# ..                          ...         ...        ...        ...
# 60                      Sicario        2015   30000000   46875468
# 99      Tucker and Dale vs Evil        2010    5000000     223838
# 46  Scott Pilgrim vs. the World        2010   60000000   31494270
# 52                Lone Survivor        2013   40000000  125069696
# 22                         Hugo        2011  170000000   73820094
#
#            actor_1_name       actor_2_name          actor_3_name  \
# 27    Leonardo DiCaprio          Tom Hardy  Joseph Gordon-Levitt
# ...

# %%
#Creating new variable with all values of genres
combined_genre=sorted_movies.loc[:,'genre_1':'genre_3']
# creating a new column and using lamda function . Since NaN != NaN
sorted_movies['genree']=combined_genre.applymap(lambda value : 1 if value == value else 0).sum(axis=1)

sorted_movies
# Out:
#                           Title  title_year     budget      Gross  \
# 27                    Inception        2010  160000000  292568851
# 26                 Interstellar        2014  165000000  187991439
# 95                     Whiplash        2014    3300000   13092000
# 8         The Dark Knight Rises        2012  250000000  448130642
# 35             Django Unchained        2012  100000000  162804648
# ..                          ...         ...        ...        ...
# 60                      Sicario        2015   30000000   46875468
# 99      Tucker and Dale vs Evil        2010    5000000     223838
# 46  Scott Pilgrim vs. the World        2010   60000000   31494270
# 52                Lone Survivor        2013   40000000  125069696
# 22                         Hugo        2011  170000000   73820094
#
#            actor_1_name       actor_2_name          actor_3_name  \
# 27    Leonardo DiCaprio          Tom Hardy  Joseph Gordon-Levitt
# ...

# %%
# Now count the occurence of 3 ,2 ,1 ie movies with 1 genre only , 2 genres only , 3 genres only
one_genre_only = sorted_movies.loc[sorted_movies['genree']==1,'Title'].count()
two_genres_only = sorted_movies.loc[sorted_movies['genree']==2,'Title'].count()
three_genres_only = sorted_movies.loc[sorted_movies['genree']==3,'Title'].count()

# %%
# Counting total movies
total_movies = sorted_movies['Title'].count()

# %%
# Calculating Percentage based on genres and rounded of the deciaml to 0 decimal places
print(f'The percentage of the top-rated movies that are in 1 genre only is {(one_genre_only/total_movies)*100:.0f}%')
print(f'The percentage of the top-rated movies that are in 2 genres only is {(two_genres_only/total_movies)*100:.0f}%')
print(f'The percentage of the top-rated movies that are in 3 genres only is {(three_genres_only/total_movies)*100:.0f}%')
# Out:
# The percentage of the top-rated movies that are in 1 genre only is 3%
# The percentage of the top-rated movies that are in 2 genres only is 23%
# The percentage of the top-rated movies that are in 3 genres only is 74%

# %% [markdown]
# ## For the above case we proceeded with follwing steps:

# %% [markdown]
# 1. First we created a variable that contains all the values of all three genre's.
#
#
# 2. We then created a new column **_genree_** in which we will fill in the values as per requirement
#    - We used a lambda function in which we assigned every value other than NaN equal to 1, since NaN        is not equal to Nan.
#    - We summed all the values row wise and filled in these values to new column "**_genree_**"
#
#
# 3. Counted the total number of movies.
#
#
# 4. Calculated the Percentage

# %%
# running the dataframe once again
detailed_movies
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %%
# filtering for required columns, wont be assigning to a variable as we need to show it in our original DataFrame
# Converting values into millions and rounding of to 3 decimal places

movies[['budget','Gross']]=movies.loc[:,['budget','Gross']].apply(lambda values : round(values/1000000,3))

# %%
movies
# Out:
#                                            Title  title_year  budget    Gross  \
# 0                                     La La Land        2016    30.0  151.102
# 1                                       Zootopia        2016   150.0  341.268
# 2                                           Lion        2016    12.0   51.739
# 3                                        Arrival        2016    47.0  100.546
# 4                          Manchester by the Sea        2016     9.0   47.695
# ..                                           ...         ...     ...      ...
# 95                                      Whiplash        2014     3.3   13.092
# 96                               Before Midnight        2013     3.0    8.115
# 97    Star Wars: Episode VII - The Force Awakens        2015   245.0  936.662
# 98  Harry Potter and the Deathly Hallows: Part I        2010   150.0  296.348
# 99                       Tucker and Dale vs Evil        2010     5.0    0.224
#
# ...

# %% [markdown]
# ## We needed to convert the value of _'budget'_ and _'Gross'_ into million dollars and round it nearest 3 decimal places
# ### Further modifications we could have done and steps involved will be detailed below:

# %% [markdown]
# 1. We modified our columns **_budget_** and **_Gross_** and used a `lambda` function and `loc()`      function to  manipulate the values inside the columns.
# 2. By using the `loc() `function we specified what columns to operate on.
# 3. By `Lambda` function we were able to convert each value by providing a condiotion using if  statement.

# %% [markdown]
# ### Further modifications :
#  In the manipulated columns we could have added a dollar sign to each value but for that , we first needed to cahange each value to string and then concatenate them with a dollar sign.
#  Did not prefer that as we might have to perform some more operations on the columns and by including a dollar sign it would become more hectic

# %%
# Crreating a column profit.(profit = Gross - budget)
movies['Profit']= movies['Gross']-movies['budget']

# %%
movies
# Out:
#                                            Title  title_year  budget    Gross  \
# 0                                     La La Land        2016    30.0  151.102
# 1                                       Zootopia        2016   150.0  341.268
# 2                                           Lion        2016    12.0   51.739
# 3                                        Arrival        2016    47.0  100.546
# 4                          Manchester by the Sea        2016     9.0   47.695
# ..                                           ...         ...     ...      ...
# 95                                      Whiplash        2014     3.3   13.092
# 96                               Before Midnight        2013     3.0    8.115
# 97    Star Wars: Episode VII - The Force Awakens        2015   245.0  936.662
# 98  Harry Potter and the Deathly Hallows: Part I        2010   150.0  296.348
# 99                       Tucker and Dale vs Evil        2010     5.0    0.224
#
# ...

# %%
# sorting the data frame by profit in descending order ie highest to lowest and craeting a new variable for it
top_profit=movies.sort_values(by='Profit',ascending=False)

# %%
# Getting all the details for top10 movies
top_profit.head(10)
# Out:
#                                          Title  title_year  budget    Gross  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0  936.662
# 11                                The Avengers        2012   220.0  623.280
# 47                                    Deadpool        2016    58.0  363.024
# 32             The Hunger Games: Catching Fire        2013   130.0  424.646
# 12                                 Toy Story 3        2010   200.0  414.984
# 8                        The Dark Knight Rises        2012   250.0  448.131
# 45                              The Lego Movie        2014    60.0  257.756
# 1                                     Zootopia        2016   150.0  341.268
# 41                               Despicable Me        2010    69.0  251.502
# 18                                  Inside Out        2015   175.0  356.454
#
#          actor_1_name       actor_2_name           actor_3_name  \
# 97        Doug Walker         Rob Walker                      0
# ...

# %% [markdown]
# ## Created a column _Profit_ in the DataFrame and added values to it
# #### As profit in this case will be equal to (**_Gross_** - **_budget_** )
# - We then sorted the DataFrame as per the **_Profit_** column from highest to lowest.
# - Then showed the top 10 movies by using the **_.head()_** metod.

# %%
detailed_movies
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %%
# creating a list using list comprehension for desired column.
list1 = [x for x in detailed_movies['actor_1_name']]

# %%
list2 = [x for x in detailed_movies['actor_2_name']]

# %%
list3 = [x for x in detailed_movies['actor_3_name']]
# removing _'0'_ from list 3 
list3.remove('0')

# %%
# concatinating lists into 1 list
list4 = list1 + list2 + list3

# %%
# Creating a new list of alphabetically sorted values
actors=sorted(list4)

# %%
# removing duplicates and appending the values in a empty list
top_actors=[]
for values in actors:
    if values not in top_actors:
        top_actors.append(values)
print(top_actors)
# Out:
# ['Abraham Benrubi', 'Adam Brown', 'Aidan Quinn', 'Aidan Turner', 'Albert Brooks', 'Albert Finney', 'Aldis Hodge', 'Alexandra Maria Lara', 'Alfred Enoch', 'Alison Brie', 'Allen Leech', 'America Ferrera', 'Amiée Conn', 'Amy Adams', 'Amy Poehler', 'Amy Ryan', 'Amy Warren', 'Andrew Garfield', 'Anna Kendrick', 'Anne Hathaway', 'Ariane Labed', 'Athina Rachel Tsangari', 'Ato Essandoh', 'Audrey Fleurot', 'Basher Savage', 'Ben Foster', 'Benedict Cumberbatch', 'Benedict Wong', 'Bernardo Saracino', 'Beth Grant', 'Bill Murray', 'Billy Crudup', 'Bob Balaban', 'Brad Garrett', 'Brad Pitt', 'Bradley Cooper', 'Brian Johnson', "Brian d'Arcy James", 'Bruce Dern', 'Bruce Green', 'Bruce Greenwood', 'Bruce Willis', 'Bryce Dallas Howard', 'BÃ©rÃ©nice Bejo', 'Casey Affleck', 'Charlie Talbert', 'Charlize Theron', 'Chelan Simmons', 'Chiwetel Ejiofor', 'ChloÃ« Grace Moretz', 'Chris Evans', 'Chris Hemsworth', 'Chris Mulkey', 'Chris Pine', 'Christian Bale', 'Christoph Waltz', 'Christopher Lee', 'Clea DuVall', 'C
# ...

# %% [markdown]
# ## Sorting the Actor names alphabetically
# ### Genrated a list of all the actors and sorted them by their First Name

# %% [markdown]
# 1. Created three seprate lists from 3 different columns
# 2. Removed any non alphabeticall string
# 3. Concatinated all the lists into 1 list
# 4. Sorted the lists alphabetically
# 5. Removed any duplicates

# %% [markdown]
# # Note:
#  We could have obatined the list of only first names by using the **_split()_** function

# %%
#Creating a sries of top actors ,since the movies are already sorted as per imdb rating and using the append function
top = pd.Series(movies['actor_1_name']._append(movies['actor_2_name'])._append(movies['actor_3_name']))

# %%
# Counting the occurence of each actor and by default ascending = false
top_3_=top.value_counts()

#convert the series into list 
top_3_actors=list(top_3_.head(3).index)

# %%
print(f'The top 3 actors that appeared in the most top rated movies are :\n{top_3_actors}')
# Out:
# The top 3 actors that appeared in the most top rated movies are :
# ['Tom Hardy', 'Leonardo DiCaprio', 'Jennifer Lawrence']

# %% [markdown]
# # Top Rated Actors
# ## Since we had already sorted our movies as per top IMDB rating and assigned them to a variable ,then we proceeded  in following manner

# %% [markdown]
# 1. Created a **Series** of top actors using the columns from DataFrame.
# 2. Filtered out top 3 actors by using the `.head()` method.
# 3. Converted the series into list using `list()`.
# 4. Printed out only the index in the list.

# %%
# creating a data frame with its ocuurence in the original data frame
country_based = sorted_movies['Country'].value_counts().to_frame()

# %%
country_based
# Out:
#            count
# Country
# USA           81
# UK            11
# Australia      3
# France         3
# Spain          1
# Canada         1

# %%
#plotting a bar chart, defining its y axis and figure size
country_based.plot(kind='bar',y='count',figsize=(8,4));
# definig Title of Bar chart
plt.title('Number of Top Rated Movies across Countries')
# defining x axis
plt.xlabel('Countries')
# defining yaxis
plt.ylabel('Count')
plt.show()

# %%
# getting the key of maximum value
country1 =country_based.idxmax().max()
print(f'The Country that produced the most number of top rated movies is {country1}')
# Out:
# The Country that produced the most number of top rated movies is USA

# %% [markdown]
# ### Created a new DataFrame of countries and count being the number of times the country appeared in original DataFrame

# %% [markdown]
#  Plotted a Bar type Graph  for its visualisation

# %% [markdown]
#  Printed the Country which has produced most number of top rated movies using the `max( )` and `idxmax( )_ function`

# %% [markdown]
# # This is the end of our analysis
